# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Asus\Downloads/LoanAmountlPrediction.csv")
df
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002    Male      No         0.0      Graduate            No
# 1    LP001003    Male     Yes         1.0      Graduate            No
# 2    LP001005    Male     Yes         0.0      Graduate           Yes
# 3    LP001006    Male     Yes         0.0  Not Graduate            No
# 4    LP001008    Male      No         0.0      Graduate            No
# ..        ...     ...     ...         ...           ...           ...
# 593  LP002978  Female      No         0.0      Graduate            No
# 594  LP002979    Male     Yes         3.0      Graduate            No
# 595  LP002983    Male     Yes         1.0      Graduate            No
# 596  LP002984    Male     Yes         2.0      Graduate            No
# 597  LP002990  Female      No         0.0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.shape
# Out:
# (598, 13)

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married  Dependents Education Self_Employed  \
# 593  LP002978  Female      No         0.0  Graduate            No
# 594  LP002979    Male     Yes         3.0  Graduate            No
# 595  LP002983    Male     Yes         1.0  Graduate            No
# 596  LP002984    Male     Yes         2.0  Graduate            No
# 597  LP002990  Female      No         0.0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 593             2900                0.0        71.0             360.0
# 594             4106                0.0        40.0             180.0
# 595             8072              240.0       253.0             360.0
# 596             7583                0.0       187.0             360.0
# 597             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 593             1.0         Rural           Y
# 594             1.0         Rural           Y
# ...

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           12
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           21
# Loan_Amount_Term     14
# Credit_History       49
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
from sklearn.impute import KNNImputer
x=df[['Dependents','LoanAmount','Loan_Amount_Term','Credit_History']]
imputer=KNNImputer(n_neighbors=2)
x=imputer.fit_transform(x)

# %%
df[['Dependents','LoanAmount','Loan_Amount_Term','Credit_History']]=pd.DataFrame(x,columns=['Dependents','LoanAmount','Loan_Amount_Term','Credit_History'])

# %%
df.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents           float64
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x="Gender",y="LoanAmount",color="Red")
plt.title("LoanAmount vs Gender")
# Out:
# Text(0.5, 1.0, 'LoanAmount vs Gender')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x="Gender",y="LoanAmount",color="Red")
plt.title("LoanAmount vs Gender")
# Out:
# Text(0.5, 1.0, 'LoanAmount vs Gender')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x="Loan_ID",y="LoanAmount",color="Red")
plt.title("LoanAmount vs Loan_ID")
# Out:
# Text(0.5, 1.0, 'LoanAmount vs Loan_ID')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x="Dependents",y="LoanAmount",color="Red")
plt.title("LoanAmount vs Dependents")
# Out:
# Text(0.5, 1.0, 'LoanAmount vs Dependents')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x="Education",y="LoanAmount",color="Red")
plt.title("LoanAmount vs Education")
# Out:
# Text(0.5, 1.0, 'LoanAmount vs Education')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x="Self_Employed",y="LoanAmount",color="Red")
plt.title("LoanAmount vs Self_Employed")
# Out:
# Text(0.5, 1.0, 'LoanAmount vs Self_Employed')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x="ApplicantIncome",y="LoanAmount",color="Red")
plt.title("LoanAmount vs ApplicantIncome")
# Out:
# Text(0.5, 1.0, 'LoanAmount vs ApplicantIncome')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x="CoapplicantIncome",y="LoanAmount",color="Red")
plt.title("LoanAmount vs CoapplicantIncome")
# Out:
# Text(0.5, 1.0, 'LoanAmount vs CoapplicantIncome')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x="Loan_Amount_Term",y="LoanAmount",color="Red")
plt.title("LoanAmount vs Loan_Amount_Term")
# Out:
# Text(0.5, 1.0, 'LoanAmount vs Loan_Amount_Term')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x="Credit_History",y="LoanAmount",color="Red")
plt.title("LoanAmount vs Credit_History")
# Out:
# Text(0.5, 1.0, 'LoanAmount vs Credit_History')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x="Property_Area",y="LoanAmount",color="Red")
plt.title("LoanAmount vs Property_Area")
# Out:
# Text(0.5, 1.0, 'LoanAmount vs Property_Area')

# %%
plt.figure(figsize=(9,8))
sns.boxplot(data=df,x="Loan_Status",y="LoanAmount",color="Red")
plt.title("LoanAmount vs Loan_Status")
# Out:
# Text(0.5, 1.0, 'LoanAmount vs Loan_Status')

# %%
plt.figure(figsize=(20,10))
plt.title('LoanAmount vs ApplicantIncome',fontsize=15)
sns.scatterplot(x=df['LoanAmount'],y=df['ApplicantIncome'],color='Black')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.title('LoanAmount vs CoapplicantIncome',fontsize=15)
sns.scatterplot(x=df['LoanAmount'],y=df['CoapplicantIncome'],color='Black')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.title('LoanAmount vs Loan_Amount_Term',fontsize=15)
sns.scatterplot(x=df['LoanAmount'],y=df['Loan_Amount_Term'],color='Black')
plt.show()

# %%
plt.figure(figsize=(10,9))
plt.title('LoanAmount vs Credit_History ',fontsize=15)
sns.scatterplot(x=df['Credit_History'],y=df['LoanAmount'])
plt.show()

# %%
numerical_df=df.select_dtypes(include=['float','int64'])
numerical_df.corr(method='spearman')*100
# Out:
#                    Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Dependents         100.000000        13.446190          -3.295533   15.893782
# ApplicantIncome     13.446190       100.000000         -30.467669   49.629698
# CoapplicantIncome   -3.295533       -30.467669         100.000000   23.477037
# LoanAmount          15.893782        49.629698          23.477037  100.000000
# Loan_Amount_Term   -12.311149        -3.244334          -1.375909    5.014489
# Credit_History      -7.988056         1.918254          -0.400453   -2.084951
#
#                    Loan_Amount_Term  Credit_History
# Dependents               -12.311149       -7.988056
# ApplicantIncome           -3.244334        1.918254
# CoapplicantIncome         -1.375909       -0.400453
# LoanAmount                 5.014489       -2.084951
# Loan_Amount_Term         100.000000        4.597146
# Credit_History             4.597146      100.000000

# %%
dff = df.drop(columns=['Loan_ID'])
dff.head()
# Out:
#   Gender Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No         0.0      Graduate            No             5849
# 1   Male     Yes         1.0      Graduate            No             4583
# 2   Male     Yes         0.0      Graduate           Yes             3000
# 3   Male     Yes         0.0  Not Graduate            No             2583
# 4   Male      No         0.0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0        93.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()
dff['Gender']=labelencoder.fit_transform(df['Gender'])
dff['Married']=labelencoder.fit_transform(df['Married'])
dff['Education']=labelencoder.fit_transform(df['Education'])
dff['Self_Employed']=labelencoder.fit_transform(df['Self_Employed'])
dff['Property_Area']=labelencoder.fit_transform(df['Property_Area'])
dff['Loan_Status']=labelencoder.fit_transform(df['Loan_Status'])
dff.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0         0.0          0              0             5849
# 1       1        1         1.0          0              0             4583
# 2       1        1         0.0          0              1             3000
# 3       1        1         0.0          1              0             2583
# 4       1        0         0.0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0        93.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              0            0
# ...

# %%
Q1=dff.quantile(0.25)
Q3 =dff.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Gender                  0.00
# Married                 1.00
# Dependents              1.00
# Education               0.00
# Self_Employed           0.00
# ApplicantIncome      2868.50
# CoapplicantIncome    2324.00
# LoanAmount             67.75
# Loan_Amount_Term        0.00
# Credit_History          0.00
# Property_Area           2.00
# Loan_Status             1.00
# dtype: float64

# %%
dfout = dff[~((dff < (Q1 - 1.5 * IQR)) |(dff > (Q3 + 1.5 * IQR))).any(axis=1)] #removing outliers from whole data set.
dfout.shape
# Out:
# (187, 12)

# %%
sns.boxplot(x=dfout['Gender'])
# Out:
# <Axes: xlabel='Gender'>

# %%
sns.boxplot(x=dfout['Married'])
# Out:
# <Axes: xlabel='Married'>

# %%
sns.boxplot(x=dfout['Dependents'])
# Out:
# <Axes: xlabel='Dependents'>

# %%
sns.boxplot(x=dfout['Education'])
# Out:
# <Axes: xlabel='Education'>

# %%
sns.boxplot(x=dfout['ApplicantIncome'])
# Out:
# <Axes: xlabel='ApplicantIncome'>

# %%
sns.boxplot(x=dfout['CoapplicantIncome'])
# Out:
# <Axes: xlabel='CoapplicantIncome'>

# %%
sns.boxplot(x=dfout['Credit_History' ])
# Out:
# <Axes: xlabel='Credit_History'>

# %%
sns.boxplot(x=dfout['Property_Area'])
# Out:
# <Axes: xlabel='Property_Area'>

# %%
x =dff.drop(['LoanAmount'],axis=1)
x
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0         0.0          0              0             5849
# 1         1        1         1.0          0              0             4583
# 2         1        1         0.0          0              1             3000
# 3         1        1         0.0          1              0             2583
# 4         1        0         0.0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 593       0        0         0.0          0              0             2900
# 594       1        1         3.0          0              0             4106
# 595       1        1         1.0          0              0             8072
# 596       1        1         2.0          0              0             7583
# 597       0        0         0.0          0              1             4583
#
# ...

# %%
y = dff['LoanAmount']
y
# Out:
# 0       93.0
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 593     71.0
# 594     40.0
# 595    253.0
# 596    187.0
# 597    133.0
# Name: LoanAmount, Length: 598, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size = 0.3,
                                                    random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.49026124, -1.3649226 , -0.73396531, ...,  0.45287064,
#          1.24940173,  0.69067489],
#        [-2.03972886, -1.3649226 , -0.73396531, ...,  0.45287064,
#         -0.02127935,  0.69067489],
#        [ 0.49026124,  0.73264228, -0.73396531, ..., -0.93904058,
#          1.24940173,  0.69067489],
#        ...,
#        [ 0.49026124,  0.73264228,  1.27452896, ...,  0.45287064,
#          1.24940173,  0.69067489],
#        [ 0.49026124,  0.73264228,  1.27452896, ...,  0.45287064,
#          1.24940173,  0.69067489],
#        [ 0.49026124, -1.3649226 , -0.73396531, ...,  0.45287064,
#         -1.29196043,  0.69067489]])

# %%
y_test
# Out:
# 127    650.0
# 48     144.0
# 485    111.0
# 407     60.0
# 225     42.0
#        ...
# 441    125.0
# 397    115.0
# 134     88.0
# 339    126.0
# 579    110.0
# Name: LoanAmount, Length: 180, dtype: float64

# %%
x_train
# Out:
# array([[ 0.49026124,  0.73264228, -0.73396531, ...,  0.45287064,
#         -1.29196043,  0.69067489],
#        [ 0.49026124, -1.3649226 , -0.73396531, ..., -2.3309518 ,
#         -1.29196043, -1.44785921],
#        [-2.03972886, -1.3649226 , -0.73396531, ...,  0.45287064,
#         -1.29196043, -1.44785921],
#        ...,
#        [ 0.49026124, -1.3649226 , -0.73396531, ..., -2.3309518 ,
#         -1.29196043, -1.44785921],
#        [-2.03972886, -1.3649226 , -0.73396531, ...,  0.45287064,
#          1.24940173,  0.69067489],
#        [ 0.49026124,  0.73264228,  1.27452896, ...,  0.45287064,
#          1.24940173,  0.69067489]])

# %%
y_train
# Out:
# 405    110.0
# 250    115.0
# 333     46.0
# 224    104.0
# 312    155.0
#        ...
# 277     54.0
# 9      349.0
# 359    124.0
# 192    120.0
# 559    275.0
# Name: LoanAmount, Length: 418, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Create and train the Linear Regression model
model_lr = LinearRegression()
model_lr.fit(x_train, y_train)

# Make predictions
y_pred_lr = model_lr.predict(x_test)

# Calculate performance metrics
mae_lr = mean_absolute_error(y_test, y_pred_lr)
mse_lr = mean_squared_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(mse_lr)
mape_lr = np.mean(np.abs((y_test - y_pred_lr) / np.abs(y_test)))
accuracy_lr = 100 * (1 - mape_lr)

# Print the performance metrics for Linear Regression
print('Linear Regression Metrics:')
print('Mean Absolute Error (MAE):', mae_lr)
print('Mean Squared Error (MSE):', mse_lr)
print('Root Mean Squared Error (RMSE):', rmse_lr)
print('Mean Absolute Percentage Error (MAPE):', round(mape_lr * 100, 2))
print('Accuracy:', round(accuracy_lr, 2))
# Out:
# Linear Regression Metrics:
# Mean Absolute Error (MAE): 48.00494363464562
# Mean Squared Error (MSE): 8009.928168774447
# Root Mean Squared Error (RMSE): 89.49820204213293
# Mean Absolute Percentage Error (MAPE): 47.27
# Accuracy: 52.73

# %%
from sklearn.tree import DecisionTreeRegressor

# Create and train the Decision Tree model
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

# Make predictions
y_pred = model.predict(x_test)

# Calculate performance metrics
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mape = np.mean(np.abs((y_test - y_pred) / np.abs(y_test)))
accuracy = 100 * (1 - mape)

# Print the performance metrics
print('Mean Absolute Error (MAE):', mae)
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
print('Accuracy:', round(accuracy, 2))
# Out:
# Mean Absolute Error (MAE): 57.49166666666667
# Mean Squared Error (MSE): 9663.906944444445
# Root Mean Squared Error (RMSE): 98.3051725213096
# Mean Absolute Percentage Error (MAPE): 55.34
# Accuracy: 44.66

# %%
from sklearn.ensemble import RandomForestRegressor

# Create and train the Random Forest model
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(x_train, y_train)

# Make predictions
y_pred_rf = model_rf.predict(x_test)

# Calculate performance metrics
mae_rf = mean_absolute_error(y_test, y_pred_rf)
mse_rf = mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mse_rf)
mape_rf = np.mean(np.abs((y_test - y_pred_rf) / np.abs(y_test)))
accuracy_rf = 100 * (1 - mape_rf)

# Print the performance metrics for Random Forest
print('Random Forest Metrics:')
print('Mean Absolute Error (MAE):', mae_rf)
print('Mean Squared Error (MSE):', mse_rf)
print('Root Mean Squared Error (RMSE):', rmse_rf)
print('Mean Absolute Percentage Error (MAPE):', round(mape_rf * 100, 2))
print('Accuracy:', round(accuracy_rf, 2))
# Out:
# Random Forest Metrics:
# Mean Absolute Error (MAE): 46.05350000000001
# Mean Squared Error (MSE): 6109.214261414814
# Root Mean Squared Error (RMSE): 78.16146276404258
# Mean Absolute Percentage Error (MAPE): 45.83
# Accuracy: 54.17

# %%
import xgboost as xgb
model_xgb = xgb.XGBRegressor()
model_xgb.fit(x_train, y_train)

# Make predictions
y_pred_xgb = model_xgb.predict(x_test)

# Calculate performance metrics
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
mape_xgb = np.mean(np.abs((y_test - y_pred_xgb) / np.abs(y_test)))
accuracy_xgb= 100 * (1 - mape_xgb)

# Print the performance metrics for Random Forest
print('XGBoost Metrics:')
print('Mean Absolute Error (MAE):', mae_xgb)
print('Mean Squared Error (MSE):', mse_xgb)
print('Root Mean Squared Error (RMSE):', rmse_xgb)
print('Mean Absolute Percentage Error (MAPE):', round(mape_xgb* 100, 2))
print('Accuracy:', round(accuracy_xgb, 2))
# Out:
# XGBoost Metrics:
# Mean Absolute Error (MAE): 45.96549235449897
# Mean Squared Error (MSE): 6493.336523512219
# Root Mean Squared Error (RMSE): 80.58124175955729
# Mean Absolute Percentage Error (MAPE): 46.69
# Accuracy: 53.31

# %%
from sklearn.model_selection import ShuffleSplit,cross_val_score
model=LinearRegression()
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("/nMean Cross-validation Accuracy:",np.mean(results))
# Out:
# [0.36154755 0.28524589 0.2237237  0.39124734 0.18505687 0.35622911
#  0.2007292  0.1434304  0.47303781 0.17131132]
# /nMean Cross-validation Accuracy: 0.27915591975945675

# %%
from sklearn.model_selection import ShuffleSplit,cross_val_score
model=DecisionTreeRegressor()
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("/nMean Cross-validation Accuracy:",np.mean(results))
# Out:
# [ 0.11516716 -0.10938558 -0.01291299 -0.45407893 -0.08162543  0.07496995
#  -0.23480136  0.27337401  0.01650317 -0.21617053]
# /nMean Cross-validation Accuracy: -0.06289605151076097

# %%
from sklearn.model_selection import ShuffleSplit,cross_val_score
model=RandomForestRegressor()
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("/nMean Cross-validation Accuracy:",np.mean(results))
# Out:
# [0.40628924 0.42498285 0.46915381 0.32654316 0.30702059 0.24546032
#  0.31891183 0.18385678 0.22316386 0.1012248 ]
# /nMean Cross-validation Accuracy: 0.30066072459567983

# %%
from sklearn.model_selection import ShuffleSplit,cross_val_score
model=xgb.XGBRegressor()
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("/nMean Cross-validation Accuracy:",np.mean(results))
# Out:
# [ 0.16563477  0.1880498   0.07383624  0.21162154 -0.61246646  0.27082189
#   0.04816239  0.14075303  0.17061174  0.25451969]
# /nMean Cross-validation Accuracy: 0.09115446316618307

# %%
import pickle
from sklearn.ensemble import RandomForestRegressor
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(x_train,y_train)
with open('model_lr.pkl','wb') as file:
  pickle.dump(model_rf,file)
print('Model saved successfully')
# Out:
# Model saved successfully

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
with open('sc.pkl','wb')as scaler_file:
  pickle.dump(sc,scaler_file)

# %%
pip install --upgrade streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
streamlit_code = """
import streamlit as st
import pickle
import numpy as np

# Load the trained linear regression model
with open('model_lr.pkl', 'rb') as model_file:
    model = pickle.load(model_file)

# Define mappings for categorical variables
gender_mapping = {'Male': 1, 'Female': 0}
married_mapping = {'Yes': 1, 'No': 0}
education_mapping = {'Graduate': 1, 'Not Graduate': 0}
self_employed_mapping = {'Yes': 1, 'No': 0}
property_area_mapping = {'Urban': 2, 'Semiurban': 1, 'Rural': 0}
loan_status_mapping = {'Y': 1, 'N': 0}

# Create the web app
st.title('Loan Amount Prediction App')

# User inputs
gender = st.selectbox('Gender', list(gender_mapping.keys()))
married = st.selectbox('Married', list(married_mapping.keys()))
dependents = st.number_input('Dependents', min_value=0, max_value=10, step=1)
education = st.selectbox('Education', list(education_mapping.keys()))
self_employed = st.selectbox('Self Employed', list(self_employed_mapping.keys()))
applicant_income = st.number_input('Applicant Income', min_value=0)
coapplicant_income = st.number_input('Coapplicant Income', min_value=0)
loan_amount_term = st.number_input('Loan Amount Term (in months)', min_value=0)
credit_history = st.selectbox('Credit History', [1, 0])
property_area = st.selectbox('Property Area', list(property_area_mapping.keys()))
loan_status= st.selectbox('Loan_Status', list(loan_status_mapping.keys()))
loan_status_encoded = loan_status_mapping[loan_status]
# Encode user inputs
gender_encoded = gender_mapping[gender]
married_encoded = married_mapping[married]
education_encoded = education_mapping[education]
self_employed_encoded = self_employed_mapping[self_employed]
property_area_encoded = property_area_mapping[property_area]

# Create the feature array
features = np.array([[gender_encoded, married_encoded, dependents, education_encoded, self_employed_encoded,
                      applicant_income, coapplicant_income, loan_amount_term, credit_history, property_area_encoded,loan_status_encoded]], dtype=np.float64)

# Make prediction
if st.button('Predict'):
    output = model.predict(features)
    if output[0] == 1:
        st.write('Loan Approved')
    else:
        st.write('Loan Not Approved')
"""
# Save the code to a file
import os

file_path = os.path.join(os.getcwd(), 'loanpredictionapp.py')

try:
    with open(file_path, 'w') as file:
        file.write(streamlit_code)
    print(f"File '{file_path}' has been saved.")
except Exception as e:
    print(f"Error saving file: {e}")
# Out:
# File 'C:\Users\Asus\Downloads\loanpredictionapp.py' has been saved.
